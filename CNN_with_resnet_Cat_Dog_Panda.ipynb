# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Models 
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Flatten, Dense, Dropout, Conv2D, MaxPooling2D

import os

folder_path = '/content/drive/MyDrive/animals'
for dirname, _, filenames in os.walk(folder_path): 
    print(dirname)
# Out:
# /content/drive/MyDrive/animals
# /content/drive/MyDrive/animals/panda
# /content/drive/MyDrive/animals/cats
# /content/drive/MyDrive/animals/dogs

# %%
print('Total cats images:', len(os.listdir(folder_path + '/cats')))
print('Total dogs images:', len(os.listdir(folder_path + '/dogs')))
print('Total pandas images:', len(os.listdir(folder_path + '/panda')))
# Out:
# Total cats images: 1000
# Total dogs images: 1000
# Total pandas images: 1000

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
fig = plt.figure(figsize=(10, 7))
  
# setting values to rows and column variables
rows = 2
columns = 2

# reading images
Image1 = image.load_img(folder_path + '/cats/cats_00001.jpg')
Image2 = image.load_img(folder_path + '/dogs/dogs_00001.jpg')
Image3 = image.load_img(folder_path + '/panda/panda_00001.jpg')

fig.add_subplot(rows, columns, 1)
plt.imshow(Image1)
plt.title("First")

fig.add_subplot(rows, columns, 2)
plt.imshow(Image2)
plt.title("Second")

fig.add_subplot(rows, columns, 3)
plt.imshow(Image3)
plt.title("Third")
# Out:
# Text(0.5, 1.0, 'Third')

# %%
train_datagen = ImageDataGenerator(
                fill_mode = 'nearest',
                validation_split=0.2
)

# %%
train_generator=train_datagen.flow_from_directory(
    folder_path,
    target_size=(108,108),
    color_mode='rgb',
    class_mode='categorical',
    subset='training',
)
validation_generator=train_datagen.flow_from_directory(
    folder_path,
    target_size=(108,108),
    color_mode='rgb',
    class_mode='categorical',
    subset='validation',
)
# Out:
# Found 2400 images belonging to 3 classes.
# Found 600 images belonging to 3 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.applications.resnet50.ResNet50(input_shape=(108,108,3), include_top=False)])
for layer in model.layers:
  layer.trainable = False

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(3, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  conv2d_1 (Conv2D)           (None, 2, 2, 64)          1179712
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 24,771,779
# Trainable params: 1,184,067
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    epochs=25,
                    verbose=1,
                    )
# Out:
# Epoch 1/25
# 75/75 [==============================] - 1163s 15s/step - loss: 1.5239 - accuracy: 0.7571 - val_loss: 0.4662 - val_accuracy: 0.8733
# Epoch 2/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.5314 - accuracy: 0.8817 - val_loss: 0.3600 - val_accuracy: 0.8883
# Epoch 3/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.2383 - accuracy: 0.9271 - val_loss: 0.3113 - val_accuracy: 0.9167
# Epoch 4/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.1687 - accuracy: 0.9442 - val_loss: 0.4606 - val_accuracy: 0.8967
# Epoch 5/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.1360 - accuracy: 0.9492 - val_loss: 0.3989 - val_accuracy: 0.9067
# Epoch 6/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.1507 - accuracy: 0.9617 - val_loss: 0.4683 - val_accuracy: 0.8933
# Epoch 7/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.1163 - accuracy: 0.9642 - val_loss: 0.4012 - val_accuracy: 0.9033
# Epoch 8/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0435 - accuracy: 0.9867 - val_loss: 0.5842 - val_accuracy: 0.9050
# Epoch 9/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0385 - accuracy: 0.9858 - val_loss: 0.4219 - val_accuracy: 0.9150
# Epoch 10/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0245 - accuracy: 0.9921 - val_loss: 0.3886 - val_accuracy: 0.9217
# Epoch 11/25
# 75/75 [==============================] - 133s 2s/step - loss: 0.0271 - accuracy: 0.9887 - val_loss: 0.5566 - val_accuracy: 0.9183
# Epoch 12/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0196 - accuracy: 0.9925 - val_loss: 0.5125 - val_accuracy: 0.9083
# Epoch 13/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0339 - accuracy: 0.9887 - val_loss: 0.7637 - val_accuracy: 0.9133
# Epoch 14/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0514 - accuracy: 0.9837 - val_loss: 0.5865 - val_accuracy: 0.9083
# Epoch 15/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0284 - accuracy: 0.9917 - val_loss: 0.6081 - val_accuracy: 0.8950
# Epoch 16/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0151 - accuracy: 0.9942 - val_loss: 1.1455 - val_accuracy: 0.8967
# Epoch 17/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0284 - accuracy: 0.9917 - val_loss: 0.6349 - val_accuracy: 0.9067
# Epoch 18/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.1051 - accuracy: 0.9742 - val_loss: 0.8051 - val_accuracy: 0.8800
# Epoch 19/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0690 - accuracy: 0.9804 - val_loss: 0.5710 - val_accuracy: 0.9117
# Epoch 20/25
# 75/75 [==============================] - 131s 2s/step - loss: 0.0684 - accuracy: 0.9812 - val_loss: 0.4909 - val_accuracy: 0.9050
# Epoch 21/25
# 75/75 [==============================] - 131s 2s/step - loss: 0.0470 - accuracy: 0.9846 - val_loss: 0.6415 - val_accuracy: 0.9133
# Epoch 22/25
# 75/75 [==============================] - 131s 2s/step - loss: 0.0215 - accuracy: 0.9929 - val_loss: 0.7559 - val_accuracy: 0.9050
# Epoch 23/25
# 75/75 [==============================] - 131s 2s/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.6974 - val_accuracy: 0.9083
# Epoch 24/25
# 75/75 [==============================] - 131s 2s/step - loss: 0.0041 - accuracy: 0.9979 - val_loss: 0.7726 - val_accuracy: 0.9067
# Epoch 25/25
# 75/75 [==============================] - 132s 2s/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 0.9484 - val_accuracy: 0.9033

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()
